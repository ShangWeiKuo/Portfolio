# %% [markdown]
# <a href="https://colab.research.google.com/github/ShangWeiKuo/Portfolio/blob/main/Python/Classification/Multiclass/Wafer/Wafer_classification_ResNet101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 讀取 libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline 

from keras import layers, Input, models
from keras.models import Model, Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.applications import ResNet101V2

import os
# 設定當前工作目錄
path="/content/drive/MyDrive/wafer/"
os.chdir(path)

print(os.listdir(path))

import warnings
warnings.filterwarnings("ignore")
# Out:
# ['Wafer classification_Densenet201.ipynb', 'wafer-defect-classification-by-deep-learning.ipynb', 'Untitled1.ipynb', 'Wafer detection.ipynb', 'wafer.zip', 'LSWMD.pkl', 'Wafer anomaly detection_AutoEncoder.ipynb', 'Wafer anomaly detection_Denoising AutoEncoder.ipynb', 'Wafer anomaly detection.ipynb', 'Wafer classification_KFold.ipynb', 'wafer_detection_densenet_model.h5', 'Wafer classification_Densenet201_PyTorch.ipynb', 'model', 'rawdata.npz', 'Wafer preprocess.ipynb', 'Model_evaluation_comparison.ipynb', 'Wafer classification_Densenet201_v2.ipynb', 'Wafer classification_Xception.ipynb', 'Wafer classification_Inception-v4.ipynb', 'Wafer classification_EfficientNetB7.ipynb', 'wafer_detection_mobilenet_model.h5', 'Wafer classification_MobileNet-V2.ipynb', 'Wafer classification_ResNet101.ipynb']

# %%
# 讀取資料(npz壓縮檔)
df=np.load('rawdata.npz')
X_train = df['X_train']
y_train = df['y_train']
df.close()

# %%
# 模型架構 (ResNet101V2)
def build_resnet():
    resnet = ResNet101V2(weights='imagenet', include_top=False)

    input = Input(shape=(64, 64, 3))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = resnet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(8, activation = 'softmax')(x)
 
    # model
    model = Model(input, output)
    
    optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
# 呼叫模型
model = build_resnet()
# EarlyStopping：可設定訓練提早結束的條件。
es = EarlyStopping(monitor='val_accuracy', mode='auto', verbose=1, patience=10)
# ReduceLROnPlateau：當訓練已無改善時，可以降低學習率，追求更細微的改善，找到更精準的最佳解。
Reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
# ModelCheckpoint：由於訓練過程耗時，有可能訓練一半就當掉，因此，我們可以利用這個 Callback，在每一個檢查點(Checkpoint)存檔，下次執行時，就可以從中斷點繼續訓練。
checkpoint = ModelCheckpoint('wafer_detection_resnet_model.h5', verbose=1, save_best_only=True)

# 訓練資料
History = model.fit(X_train, y_train, 
           epochs=100, 
           batch_size=64,
           verbose=2,
           callbacks=[Reduce, es, checkpoint],
           validation_split=0.2, # 每次訓練將 Train data 分割 20% 作為 Validation data
           workers=8)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171319296/171317808 [==============================] - 1s 0us/step
# 171327488/171317808 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         84
#
#  resnet101v2 (Functional)    (None, None, None, 2048)  42626560
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 43,162,460
# Trainable params: 43,060,188
# Non-trainable params: 102,272
# _________________________________________________________________
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.66210, saving model to wafer_detection_resnet_model.h5
# 256/256 - 65s - loss: 2.7773 - accuracy: 0.1909 - val_loss: 1.6621 - val_accuracy: 0.4115 - lr: 1.0000e-04 - 65s/epoch - 252ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.66210 to 0.98186, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 1.7558 - accuracy: 0.4306 - val_loss: 0.9819 - val_accuracy: 0.6975 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.98186 to 0.77737, saving model to wafer_detection_resnet_model.h5
# 256/256 - 43s - loss: 1.2102 - accuracy: 0.6097 - val_loss: 0.7774 - val_accuracy: 0.7570 - lr: 1.0000e-04 - 43s/epoch - 167ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.77737 to 0.66408, saving model to wafer_detection_resnet_model.h5
# 256/256 - 43s - loss: 0.9704 - accuracy: 0.6826 - val_loss: 0.6641 - val_accuracy: 0.7930 - lr: 1.0000e-04 - 43s/epoch - 166ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.66408 to 0.58442, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.8326 - accuracy: 0.7270 - val_loss: 0.5844 - val_accuracy: 0.8087 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.58442 to 0.52940, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.7480 - accuracy: 0.7586 - val_loss: 0.5294 - val_accuracy: 0.8264 - lr: 1.0000e-04 - 42s/epoch - 166ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.52940 to 0.48717, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.6735 - accuracy: 0.7793 - val_loss: 0.4872 - val_accuracy: 0.8359 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.48717 to 0.46887, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.6248 - accuracy: 0.7965 - val_loss: 0.4689 - val_accuracy: 0.8410 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.46887 to 0.43686, saving model to wafer_detection_resnet_model.h5
# 256/256 - 43s - loss: 0.5897 - accuracy: 0.8054 - val_loss: 0.4369 - val_accuracy: 0.8528 - lr: 1.0000e-04 - 43s/epoch - 166ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.43686 to 0.42308, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.5397 - accuracy: 0.8239 - val_loss: 0.4231 - val_accuracy: 0.8540 - lr: 1.0000e-04 - 42s/epoch - 166ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.42308 to 0.41064, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.5292 - accuracy: 0.8269 - val_loss: 0.4106 - val_accuracy: 0.8584 - lr: 1.0000e-04 - 42s/epoch - 164ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.41064 to 0.39799, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.4964 - accuracy: 0.8380 - val_loss: 0.3980 - val_accuracy: 0.8582 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.39799 to 0.39219, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.4707 - accuracy: 0.8431 - val_loss: 0.3922 - val_accuracy: 0.8619 - lr: 1.0000e-04 - 42s/epoch - 166ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.39219 to 0.38266, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.4452 - accuracy: 0.8513 - val_loss: 0.3827 - val_accuracy: 0.8653 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.38266 to 0.37553, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.4103 - accuracy: 0.8644 - val_loss: 0.3755 - val_accuracy: 0.8709 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.37553 to 0.37255, saving model to wafer_detection_resnet_model.h5
# 256/256 - 43s - loss: 0.4102 - accuracy: 0.8616 - val_loss: 0.3726 - val_accuracy: 0.8702 - lr: 1.0000e-04 - 43s/epoch - 166ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.37255 to 0.36533, saving model to wafer_detection_resnet_model.h5
# 256/256 - 43s - loss: 0.4066 - accuracy: 0.8649 - val_loss: 0.3653 - val_accuracy: 0.8744 - lr: 1.0000e-04 - 43s/epoch - 166ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.36533 to 0.35613, saving model to wafer_detection_resnet_model.h5
# 256/256 - 43s - loss: 0.3856 - accuracy: 0.8723 - val_loss: 0.3561 - val_accuracy: 0.8766 - lr: 1.0000e-04 - 43s/epoch - 167ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.35613
# 256/256 - 37s - loss: 0.3744 - accuracy: 0.8776 - val_loss: 0.3575 - val_accuracy: 0.8748 - lr: 1.0000e-04 - 37s/epoch - 144ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.35613 to 0.35091, saving model to wafer_detection_resnet_model.h5
# 256/256 - 41s - loss: 0.3548 - accuracy: 0.8824 - val_loss: 0.3509 - val_accuracy: 0.8771 - lr: 1.0000e-04 - 41s/epoch - 161ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.35091 to 0.34996, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.3455 - accuracy: 0.8877 - val_loss: 0.3500 - val_accuracy: 0.8780 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.34996 to 0.34650, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.3278 - accuracy: 0.8939 - val_loss: 0.3465 - val_accuracy: 0.8800 - lr: 1.0000e-04 - 42s/epoch - 166ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.34650 to 0.34484, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.3241 - accuracy: 0.8911 - val_loss: 0.3448 - val_accuracy: 0.8832 - lr: 1.0000e-04 - 42s/epoch - 165ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.34484
# 256/256 - 37s - loss: 0.3147 - accuracy: 0.8950 - val_loss: 0.3450 - val_accuracy: 0.8829 - lr: 1.0000e-04 - 37s/epoch - 144ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.34484 to 0.34446, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.3067 - accuracy: 0.8982 - val_loss: 0.3445 - val_accuracy: 0.8846 - lr: 1.0000e-04 - 42s/epoch - 163ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.34446
# 256/256 - 37s - loss: 0.2951 - accuracy: 0.9014 - val_loss: 0.3451 - val_accuracy: 0.8839 - lr: 1.0000e-04 - 37s/epoch - 144ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.34446
# 256/256 - 36s - loss: 0.2881 - accuracy: 0.9047 - val_loss: 0.3476 - val_accuracy: 0.8834 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.34446 to 0.34365, saving model to wafer_detection_resnet_model.h5
# 256/256 - 41s - loss: 0.2856 - accuracy: 0.9069 - val_loss: 0.3436 - val_accuracy: 0.8846 - lr: 1.0000e-04 - 41s/epoch - 162ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.34365
# 256/256 - 37s - loss: 0.2755 - accuracy: 0.9091 - val_loss: 0.3463 - val_accuracy: 0.8837 - lr: 1.0000e-04 - 37s/epoch - 144ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.34365
# 256/256 - 36s - loss: 0.2658 - accuracy: 0.9139 - val_loss: 0.3453 - val_accuracy: 0.8846 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.34365 to 0.34185, saving model to wafer_detection_resnet_model.h5
# 256/256 - 41s - loss: 0.2610 - accuracy: 0.9145 - val_loss: 0.3419 - val_accuracy: 0.8856 - lr: 1.0000e-04 - 41s/epoch - 162ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.34185
# 256/256 - 37s - loss: 0.2508 - accuracy: 0.9203 - val_loss: 0.3422 - val_accuracy: 0.8876 - lr: 1.0000e-04 - 37s/epoch - 143ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.34185
# 256/256 - 36s - loss: 0.2462 - accuracy: 0.9191 - val_loss: 0.3428 - val_accuracy: 0.8868 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.34185 to 0.33726, saving model to wafer_detection_resnet_model.h5
# 256/256 - 42s - loss: 0.2406 - accuracy: 0.9233 - val_loss: 0.3373 - val_accuracy: 0.8871 - lr: 1.0000e-04 - 42s/epoch - 162ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.33726
# 256/256 - 37s - loss: 0.2386 - accuracy: 0.9227 - val_loss: 0.3420 - val_accuracy: 0.8856 - lr: 1.0000e-04 - 37s/epoch - 144ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.2207 - accuracy: 0.9280 - val_loss: 0.3407 - val_accuracy: 0.8881 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.2258 - accuracy: 0.9298 - val_loss: 0.3373 - val_accuracy: 0.8910 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.2170 - accuracy: 0.9310 - val_loss: 0.3425 - val_accuracy: 0.8883 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.2203 - accuracy: 0.9294 - val_loss: 0.3421 - val_accuracy: 0.8895 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1993 - accuracy: 0.9360 - val_loss: 0.3424 - val_accuracy: 0.8905 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.2086 - accuracy: 0.9328 - val_loss: 0.3431 - val_accuracy: 0.8917 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.2107 - accuracy: 0.9295 - val_loss: 0.3428 - val_accuracy: 0.8927 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1999 - accuracy: 0.9353 - val_loss: 0.3455 - val_accuracy: 0.8915 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.2011 - accuracy: 0.9361 - val_loss: 0.3466 - val_accuracy: 0.8910 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1958 - accuracy: 0.9377 - val_loss: 0.3498 - val_accuracy: 0.8910 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1960 - accuracy: 0.9373 - val_loss: 0.3465 - val_accuracy: 0.8913 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1928 - accuracy: 0.9412 - val_loss: 0.3473 - val_accuracy: 0.8942 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1828 - accuracy: 0.9413 - val_loss: 0.3440 - val_accuracy: 0.8932 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1747 - accuracy: 0.9439 - val_loss: 0.3490 - val_accuracy: 0.8940 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1820 - accuracy: 0.9435 - val_loss: 0.3463 - val_accuracy: 0.8935 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1792 - accuracy: 0.9435 - val_loss: 0.3440 - val_accuracy: 0.8966 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1761 - accuracy: 0.9474 - val_loss: 0.3490 - val_accuracy: 0.8942 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1688 - accuracy: 0.9479 - val_loss: 0.3511 - val_accuracy: 0.8944 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1632 - accuracy: 0.9503 - val_loss: 0.3517 - val_accuracy: 0.8959 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1631 - accuracy: 0.9484 - val_loss: 0.3518 - val_accuracy: 0.8954 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1570 - accuracy: 0.9532 - val_loss: 0.3520 - val_accuracy: 0.8949 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1628 - accuracy: 0.9484 - val_loss: 0.3552 - val_accuracy: 0.8944 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1622 - accuracy: 0.9480 - val_loss: 0.3564 - val_accuracy: 0.8954 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1586 - accuracy: 0.9505 - val_loss: 0.3577 - val_accuracy: 0.8971 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1482 - accuracy: 0.9533 - val_loss: 0.3596 - val_accuracy: 0.8954 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1506 - accuracy: 0.9511 - val_loss: 0.3588 - val_accuracy: 0.8959 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1536 - accuracy: 0.9540 - val_loss: 0.3570 - val_accuracy: 0.8962 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1496 - accuracy: 0.9546 - val_loss: 0.3579 - val_accuracy: 0.8957 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1443 - accuracy: 0.9562 - val_loss: 0.3571 - val_accuracy: 0.8942 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1444 - accuracy: 0.9549 - val_loss: 0.3611 - val_accuracy: 0.8962 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1417 - accuracy: 0.9570 - val_loss: 0.3642 - val_accuracy: 0.8937 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1414 - accuracy: 0.9568 - val_loss: 0.3661 - val_accuracy: 0.8944 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1335 - accuracy: 0.9596 - val_loss: 0.3657 - val_accuracy: 0.8940 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.33726
# 256/256 - 36s - loss: 0.1429 - accuracy: 0.9567 - val_loss: 0.3656 - val_accuracy: 0.8935 - lr: 1.0000e-04 - 36s/epoch - 140ms/step
# Epoch 00069: early stopping

# %%
model_path = path + "model/Resnet"
model.save(model_path)
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/wafer/model/Resnet/assets

# %%
# Accuracy plot 
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# Loss plot
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
