# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 讀取 libraries
import numpy as np
import tensorflow
import matplotlib.pyplot as plt
# %matplotlib inline

from keras import Input
from keras.models import Model
from keras.layers import Dense, Dropout, Conv2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import legacy
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.applications import ResNet101V2

import os
# 設定當前工作目錄
path="/content/drive/MyDrive/wafer/"
os.chdir(path)

import warnings
warnings.filterwarnings("ignore")

# %%
# 讀取資料(npz壓縮檔)
df=np.load('rawdata.npz')
X_train = df['X_train']
y_train = df['y_train']
df.close()

# %%
# 模型架構 (ResNet101V2)
def build_resnet():
    resnet = ResNet101V2(weights='imagenet', include_top=False)

    input = Input(shape=(64, 64, 3))
    x = Conv2D(3, (3, 3), padding='same')(input)

    x = resnet(x)

    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(8, activation = 'softmax')(x)

    # model
    model = Model(input, output)

    optimizer = legacy.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
# 呼叫模型
model = build_resnet()
# EarlyStopping：可設定訓練提早結束的條件。
es = EarlyStopping(monitor='val_accuracy', mode='auto', verbose=1, patience=10)
# ReduceLROnPlateau：當訓練已無改善時，可以降低學習率，追求更細微的改善，找到更精準的最佳解。
Reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
# ModelCheckpoint：由於訓練過程耗時，有可能訓練一半就當掉，因此，我們可以利用這個 Callback，在每一個檢查點(Checkpoint)存檔，下次執行時，就可以從中斷點繼續訓練。
checkpoint = ModelCheckpoint('wafer_detection_resnet_model.h5', verbose=1, save_best_only=True)

# 訓練資料
History = model.fit(X_train, y_train,
           epochs=100,
           batch_size=64,
           verbose=2,
           callbacks=[Reduce, es, checkpoint],
           validation_split=0.2, # 每次訓練將 Train data 分割 20% 作為 Validation data
           workers=8)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 9s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         84
#
#  resnet101v2 (Functional)    (None, None, None, 2048)  42626560
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 43,162,460
# Trainable params: 43,060,188
# Non-trainable params: 102,272
# _________________________________________________________________
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.98237, saving model to wafer_detection_resnet_model.h5
# 256/256 - 63s - loss: 2.9268 - accuracy: 0.1830 - val_loss: 1.9824 - val_accuracy: 0.2929 - lr: 1.0000e-04 - 63s/epoch - 246ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.98237 to 1.15882, saving model to wafer_detection_resnet_model.h5
# 256/256 - 44s - loss: 1.8759 - accuracy: 0.4120 - val_loss: 1.1588 - val_accuracy: 0.6439 - lr: 1.0000e-04 - 44s/epoch - 172ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.15882 to 0.86232, saving model to wafer_detection_resnet_model.h5
# 256/256 - 46s - loss: 1.2542 - accuracy: 0.5989 - val_loss: 0.8623 - val_accuracy: 0.7384 - lr: 1.0000e-04 - 46s/epoch - 181ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.86232 to 0.68106, saving model to wafer_detection_resnet_model.h5
# 256/256 - 45s - loss: 0.9971 - accuracy: 0.6884 - val_loss: 0.6811 - val_accuracy: 0.7935 - lr: 1.0000e-04 - 45s/epoch - 175ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.68106 to 0.60239, saving model to wafer_detection_resnet_model.h5
# 256/256 - 40s - loss: 0.8512 - accuracy: 0.7360 - val_loss: 0.6024 - val_accuracy: 0.8070 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.60239 to 0.55240, saving model to wafer_detection_resnet_model.h5
# 256/256 - 43s - loss: 0.7521 - accuracy: 0.7660 - val_loss: 0.5524 - val_accuracy: 0.8212 - lr: 1.0000e-04 - 43s/epoch - 170ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.55240 to 0.50370, saving model to wafer_detection_resnet_model.h5
# 256/256 - 45s - loss: 0.6885 - accuracy: 0.7832 - val_loss: 0.5037 - val_accuracy: 0.8286 - lr: 1.0000e-04 - 45s/epoch - 177ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.50370 to 0.48885, saving model to wafer_detection_resnet_model.h5
# 256/256 - 44s - loss: 0.6285 - accuracy: 0.8000 - val_loss: 0.4889 - val_accuracy: 0.8315 - lr: 1.0000e-04 - 44s/epoch - 171ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.48885 to 0.46816, saving model to wafer_detection_resnet_model.h5
# 256/256 - 48s - loss: 0.5894 - accuracy: 0.8115 - val_loss: 0.4682 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 48s/epoch - 188ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.46816 to 0.45073, saving model to wafer_detection_resnet_model.h5
# 256/256 - 48s - loss: 0.5567 - accuracy: 0.8225 - val_loss: 0.4507 - val_accuracy: 0.8447 - lr: 1.0000e-04 - 48s/epoch - 188ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.45073 to 0.42629, saving model to wafer_detection_resnet_model.h5
# 256/256 - 48s - loss: 0.5243 - accuracy: 0.8309 - val_loss: 0.4263 - val_accuracy: 0.8557 - lr: 1.0000e-04 - 48s/epoch - 189ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.42629 to 0.41307, saving model to wafer_detection_resnet_model.h5
# 256/256 - 47s - loss: 0.5042 - accuracy: 0.8384 - val_loss: 0.4131 - val_accuracy: 0.8611 - lr: 1.0000e-04 - 47s/epoch - 182ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.41307
# 256/256 - 33s - loss: 0.4817 - accuracy: 0.8445 - val_loss: 0.4165 - val_accuracy: 0.8550 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.41307 to 0.39361, saving model to wafer_detection_resnet_model.h5
# 256/256 - 46s - loss: 0.4655 - accuracy: 0.8504 - val_loss: 0.3936 - val_accuracy: 0.8643 - lr: 1.0000e-04 - 46s/epoch - 178ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.39361 to 0.39123, saving model to wafer_detection_resnet_model.h5
# 256/256 - 46s - loss: 0.4361 - accuracy: 0.8595 - val_loss: 0.3912 - val_accuracy: 0.8655 - lr: 1.0000e-04 - 46s/epoch - 179ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.39123
# 256/256 - 33s - loss: 0.4253 - accuracy: 0.8622 - val_loss: 0.3932 - val_accuracy: 0.8614 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.39123 to 0.38186, saving model to wafer_detection_resnet_model.h5
# 256/256 - 47s - loss: 0.4108 - accuracy: 0.8650 - val_loss: 0.3819 - val_accuracy: 0.8690 - lr: 1.0000e-04 - 47s/epoch - 182ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.38186
# 256/256 - 33s - loss: 0.3930 - accuracy: 0.8710 - val_loss: 0.3842 - val_accuracy: 0.8695 - lr: 1.0000e-04 - 33s/epoch - 130ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.38186 to 0.37435, saving model to wafer_detection_resnet_model.h5
# 256/256 - 46s - loss: 0.3789 - accuracy: 0.8752 - val_loss: 0.3743 - val_accuracy: 0.8724 - lr: 1.0000e-04 - 46s/epoch - 179ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.37435 to 0.36762, saving model to wafer_detection_resnet_model.h5
# 256/256 - 49s - loss: 0.3797 - accuracy: 0.8771 - val_loss: 0.3676 - val_accuracy: 0.8736 - lr: 1.0000e-04 - 49s/epoch - 191ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.36762
# 256/256 - 33s - loss: 0.3602 - accuracy: 0.8802 - val_loss: 0.3766 - val_accuracy: 0.8724 - lr: 1.0000e-04 - 33s/epoch - 130ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.36762
# 256/256 - 33s - loss: 0.3374 - accuracy: 0.8880 - val_loss: 0.3678 - val_accuracy: 0.8736 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.36762 to 0.36687, saving model to wafer_detection_resnet_model.h5
# 256/256 - 49s - loss: 0.3397 - accuracy: 0.8902 - val_loss: 0.3669 - val_accuracy: 0.8756 - lr: 1.0000e-04 - 49s/epoch - 192ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.36687
# 256/256 - 33s - loss: 0.3236 - accuracy: 0.8928 - val_loss: 0.3678 - val_accuracy: 0.8736 - lr: 1.0000e-04 - 33s/epoch - 130ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.36687
# 256/256 - 33s - loss: 0.3208 - accuracy: 0.8955 - val_loss: 0.3745 - val_accuracy: 0.8761 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.36687 to 0.36028, saving model to wafer_detection_resnet_model.h5
# 256/256 - 45s - loss: 0.3051 - accuracy: 0.9008 - val_loss: 0.3603 - val_accuracy: 0.8756 - lr: 1.0000e-04 - 45s/epoch - 174ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.36028
# 256/256 - 33s - loss: 0.2958 - accuracy: 0.9021 - val_loss: 0.3616 - val_accuracy: 0.8785 - lr: 1.0000e-04 - 33s/epoch - 130ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.36028
# 256/256 - 33s - loss: 0.2961 - accuracy: 0.9021 - val_loss: 0.3657 - val_accuracy: 0.8756 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.36028
# 256/256 - 32s - loss: 0.2850 - accuracy: 0.9052 - val_loss: 0.3662 - val_accuracy: 0.8775 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.36028
# 256/256 - 32s - loss: 0.2890 - accuracy: 0.9072 - val_loss: 0.3609 - val_accuracy: 0.8771 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.36028 to 0.35937, saving model to wafer_detection_resnet_model.h5
# 256/256 - 48s - loss: 0.2761 - accuracy: 0.9084 - val_loss: 0.3594 - val_accuracy: 0.8793 - lr: 1.0000e-04 - 48s/epoch - 187ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.35937
# 256/256 - 33s - loss: 0.2698 - accuracy: 0.9102 - val_loss: 0.3603 - val_accuracy: 0.8822 - lr: 1.0000e-04 - 33s/epoch - 130ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.35937 to 0.35809, saving model to wafer_detection_resnet_model.h5
# 256/256 - 46s - loss: 0.2560 - accuracy: 0.9171 - val_loss: 0.3581 - val_accuracy: 0.8812 - lr: 1.0000e-04 - 46s/epoch - 181ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2558 - accuracy: 0.9179 - val_loss: 0.3626 - val_accuracy: 0.8802 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2570 - accuracy: 0.9179 - val_loss: 0.3608 - val_accuracy: 0.8817 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.2514 - accuracy: 0.9176 - val_loss: 0.3667 - val_accuracy: 0.8797 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2446 - accuracy: 0.9216 - val_loss: 0.3638 - val_accuracy: 0.8824 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.2408 - accuracy: 0.9213 - val_loss: 0.3729 - val_accuracy: 0.8783 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.2292 - accuracy: 0.9254 - val_loss: 0.3610 - val_accuracy: 0.8851 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.2281 - accuracy: 0.9266 - val_loss: 0.3661 - val_accuracy: 0.8849 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2219 - accuracy: 0.9293 - val_loss: 0.3696 - val_accuracy: 0.8839 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.2125 - accuracy: 0.9307 - val_loss: 0.3676 - val_accuracy: 0.8842 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2220 - accuracy: 0.9271 - val_loss: 0.3628 - val_accuracy: 0.8876 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2090 - accuracy: 0.9318 - val_loss: 0.3691 - val_accuracy: 0.8859 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2138 - accuracy: 0.9277 - val_loss: 0.3707 - val_accuracy: 0.8827 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2004 - accuracy: 0.9344 - val_loss: 0.3671 - val_accuracy: 0.8837 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1997 - accuracy: 0.9369 - val_loss: 0.3649 - val_accuracy: 0.8859 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.2030 - accuracy: 0.9353 - val_loss: 0.3678 - val_accuracy: 0.8859 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1892 - accuracy: 0.9393 - val_loss: 0.3712 - val_accuracy: 0.8871 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1929 - accuracy: 0.9395 - val_loss: 0.3690 - val_accuracy: 0.8881 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1889 - accuracy: 0.9357 - val_loss: 0.3687 - val_accuracy: 0.8854 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1839 - accuracy: 0.9408 - val_loss: 0.3685 - val_accuracy: 0.8878 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1763 - accuracy: 0.9423 - val_loss: 0.3681 - val_accuracy: 0.8878 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1807 - accuracy: 0.9434 - val_loss: 0.3687 - val_accuracy: 0.8864 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1784 - accuracy: 0.9416 - val_loss: 0.3746 - val_accuracy: 0.8856 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1740 - accuracy: 0.9440 - val_loss: 0.3724 - val_accuracy: 0.8859 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1765 - accuracy: 0.9434 - val_loss: 0.3714 - val_accuracy: 0.8881 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1714 - accuracy: 0.9437 - val_loss: 0.3724 - val_accuracy: 0.8886 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1729 - accuracy: 0.9448 - val_loss: 0.3721 - val_accuracy: 0.8873 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1683 - accuracy: 0.9459 - val_loss: 0.3748 - val_accuracy: 0.8881 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1599 - accuracy: 0.9493 - val_loss: 0.3765 - val_accuracy: 0.8859 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1707 - accuracy: 0.9453 - val_loss: 0.3777 - val_accuracy: 0.8881 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1594 - accuracy: 0.9492 - val_loss: 0.3767 - val_accuracy: 0.8908 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1547 - accuracy: 0.9514 - val_loss: 0.3754 - val_accuracy: 0.8888 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1718 - accuracy: 0.9439 - val_loss: 0.3750 - val_accuracy: 0.8873 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1591 - accuracy: 0.9488 - val_loss: 0.3770 - val_accuracy: 0.8886 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1582 - accuracy: 0.9495 - val_loss: 0.3774 - val_accuracy: 0.8908 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1546 - accuracy: 0.9502 - val_loss: 0.3810 - val_accuracy: 0.8905 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1519 - accuracy: 0.9518 - val_loss: 0.3843 - val_accuracy: 0.8891 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1508 - accuracy: 0.9544 - val_loss: 0.3821 - val_accuracy: 0.8917 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1551 - accuracy: 0.9502 - val_loss: 0.3845 - val_accuracy: 0.8886 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1434 - accuracy: 0.9527 - val_loss: 0.3856 - val_accuracy: 0.8910 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1374 - accuracy: 0.9581 - val_loss: 0.3864 - val_accuracy: 0.8891 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1426 - accuracy: 0.9551 - val_loss: 0.3862 - val_accuracy: 0.8925 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1437 - accuracy: 0.9543 - val_loss: 0.3874 - val_accuracy: 0.8888 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1367 - accuracy: 0.9562 - val_loss: 0.3891 - val_accuracy: 0.8908 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1329 - accuracy: 0.9567 - val_loss: 0.3883 - val_accuracy: 0.8925 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1317 - accuracy: 0.9589 - val_loss: 0.3882 - val_accuracy: 0.8908 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1312 - accuracy: 0.9578 - val_loss: 0.3883 - val_accuracy: 0.8900 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1376 - accuracy: 0.9564 - val_loss: 0.3907 - val_accuracy: 0.8944 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1351 - accuracy: 0.9576 - val_loss: 0.3951 - val_accuracy: 0.8883 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1338 - accuracy: 0.9578 - val_loss: 0.3923 - val_accuracy: 0.8915 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1314 - accuracy: 0.9596 - val_loss: 0.3977 - val_accuracy: 0.8910 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1234 - accuracy: 0.9617 - val_loss: 0.3945 - val_accuracy: 0.8917 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1294 - accuracy: 0.9590 - val_loss: 0.3997 - val_accuracy: 0.8888 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1302 - accuracy: 0.9600 - val_loss: 0.4005 - val_accuracy: 0.8871 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1288 - accuracy: 0.9598 - val_loss: 0.4012 - val_accuracy: 0.8888 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1243 - accuracy: 0.9612 - val_loss: 0.3967 - val_accuracy: 0.8900 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.35809
# 256/256 - 32s - loss: 0.1307 - accuracy: 0.9597 - val_loss: 0.3969 - val_accuracy: 0.8900 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.35809
# 256/256 - 33s - loss: 0.1240 - accuracy: 0.9623 - val_loss: 0.3974 - val_accuracy: 0.8905 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 90: early stopping

# %%
model_path = os.path.join(path, "model/Resnet")
model.save(model_path)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 105). These functions will not be directly callable after loading.

# %%
# Accuracy plot
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# Loss plot
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
