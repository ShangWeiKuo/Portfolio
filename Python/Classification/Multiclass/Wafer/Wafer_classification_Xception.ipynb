# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 讀取 libraries
import numpy as np
import tensorflow
import matplotlib.pyplot as plt
# %matplotlib inline

from keras import Input
from keras.models import Model
from keras.layers import Dense, Dropout, Conv2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import legacy
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.applications import Xception

import os
# 設定當前工作目錄
path="/content/drive/MyDrive/wafer/"
os.chdir(path)

import warnings
warnings.filterwarnings("ignore")

# %%
# 讀取資料(npz壓縮檔)
df=np.load('rawdata.npz')
X_train = df['X_train']
y_train = df['y_train']
df.close()

# %%
# 模型架構 (Xception)
def build_xception():
    xception = Xception(weights='imagenet', include_top=False)

    input = Input(shape=(64, 64, 3))
    x = Conv2D(3, (3, 3), padding='same')(input)

    x = xception(x)

    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(8, activation = 'softmax')(x)

    # model
    model = Model(input ,output)

    optimizer = legacy.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
# 呼叫模型
model = build_xception()
# EarlyStopping：可設定訓練提早結束的條件。
es = EarlyStopping(monitor='val_accuracy', mode='auto', verbose=1, patience=10)
# ReduceLROnPlateau：當訓練已無改善時，可以降低學習率，追求更細微的改善，找到更精準的最佳解。
Reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
# ModelCheckpoint：由於訓練過程耗時，有可能訓練一半就當掉，因此，我們可以利用這個 Callback，在每一個檢查點(Checkpoint)存檔，下次執行時，就可以從中斷點繼續訓練。
checkpoint = ModelCheckpoint('wafer_detection_xception_model.h5', verbose=1, save_best_only=True)

# 訓練資料
History = model.fit(X_train, y_train,
           epochs=100,
           batch_size=64,
           verbose=2,
           callbacks=[Reduce, es, checkpoint],
           validation_split=0.2, # 每次訓練將 Train data 分割 20% 作為 Validation data
           workers=8)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 3)         84
#
#  xception (Functional)       (None, None, None, 2048)  20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization_4 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 21,397,380
# Trainable params: 21,338,244
# Non-trainable params: 59,136
# _________________________________________________________________
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.76788, saving model to wafer_detection_xception_model.h5
# 256/256 - 60s - loss: 2.8002 - accuracy: 0.1815 - val_loss: 1.7679 - val_accuracy: 0.3622 - lr: 1.0000e-04 - 60s/epoch - 233ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.76788 to 1.32903, saving model to wafer_detection_xception_model.h5
# 256/256 - 44s - loss: 1.9707 - accuracy: 0.3470 - val_loss: 1.3290 - val_accuracy: 0.5229 - lr: 1.0000e-04 - 44s/epoch - 172ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.32903 to 1.19665, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 1.7215 - accuracy: 0.4254 - val_loss: 1.1966 - val_accuracy: 0.5640 - lr: 1.0000e-04 - 46s/epoch - 182ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.19665 to 1.09620, saving model to wafer_detection_xception_model.h5
# 256/256 - 43s - loss: 1.5431 - accuracy: 0.4743 - val_loss: 1.0962 - val_accuracy: 0.5949 - lr: 1.0000e-04 - 43s/epoch - 167ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.09620 to 1.04329, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 1.4492 - accuracy: 0.5011 - val_loss: 1.0433 - val_accuracy: 0.6130 - lr: 1.0000e-04 - 47s/epoch - 184ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.04329 to 0.97544, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 1.3530 - accuracy: 0.5287 - val_loss: 0.9754 - val_accuracy: 0.6478 - lr: 1.0000e-04 - 47s/epoch - 183ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.97544 to 0.92434, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 1.2599 - accuracy: 0.5595 - val_loss: 0.9243 - val_accuracy: 0.6647 - lr: 1.0000e-04 - 47s/epoch - 182ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.92434 to 0.87443, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 1.1869 - accuracy: 0.5818 - val_loss: 0.8744 - val_accuracy: 0.6975 - lr: 1.0000e-04 - 47s/epoch - 183ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.87443 to 0.83155, saving model to wafer_detection_xception_model.h5
# 256/256 - 43s - loss: 1.1478 - accuracy: 0.5988 - val_loss: 0.8315 - val_accuracy: 0.7284 - lr: 1.0000e-04 - 43s/epoch - 169ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.83155 to 0.79317, saving model to wafer_detection_xception_model.h5
# 256/256 - 45s - loss: 1.0662 - accuracy: 0.6316 - val_loss: 0.7932 - val_accuracy: 0.7394 - lr: 1.0000e-04 - 45s/epoch - 176ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.79317 to 0.76108, saving model to wafer_detection_xception_model.h5
# 256/256 - 43s - loss: 1.0344 - accuracy: 0.6414 - val_loss: 0.7611 - val_accuracy: 0.7443 - lr: 1.0000e-04 - 43s/epoch - 170ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.76108 to 0.73684, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.9882 - accuracy: 0.6613 - val_loss: 0.7368 - val_accuracy: 0.7482 - lr: 1.0000e-04 - 47s/epoch - 183ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.73684 to 0.71404, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.9595 - accuracy: 0.6732 - val_loss: 0.7140 - val_accuracy: 0.7543 - lr: 1.0000e-04 - 47s/epoch - 182ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.71404 to 0.70182, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.9171 - accuracy: 0.6860 - val_loss: 0.7018 - val_accuracy: 0.7597 - lr: 1.0000e-04 - 48s/epoch - 186ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.70182 to 0.67905, saving model to wafer_detection_xception_model.h5
# 256/256 - 43s - loss: 0.8998 - accuracy: 0.6921 - val_loss: 0.6790 - val_accuracy: 0.7656 - lr: 1.0000e-04 - 43s/epoch - 170ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.67905 to 0.66410, saving model to wafer_detection_xception_model.h5
# 256/256 - 43s - loss: 0.8721 - accuracy: 0.7019 - val_loss: 0.6641 - val_accuracy: 0.7666 - lr: 1.0000e-04 - 43s/epoch - 166ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.66410 to 0.66014, saving model to wafer_detection_xception_model.h5
# 256/256 - 44s - loss: 0.8607 - accuracy: 0.7030 - val_loss: 0.6601 - val_accuracy: 0.7710 - lr: 1.0000e-04 - 44s/epoch - 173ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.66014 to 0.63931, saving model to wafer_detection_xception_model.h5
# 256/256 - 45s - loss: 0.8386 - accuracy: 0.7149 - val_loss: 0.6393 - val_accuracy: 0.7820 - lr: 1.0000e-04 - 45s/epoch - 176ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.63931 to 0.62606, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 0.8163 - accuracy: 0.7212 - val_loss: 0.6261 - val_accuracy: 0.7864 - lr: 1.0000e-04 - 46s/epoch - 180ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.62606 to 0.61509, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.8025 - accuracy: 0.7251 - val_loss: 0.6151 - val_accuracy: 0.7923 - lr: 1.0000e-04 - 47s/epoch - 183ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.61509 to 0.61141, saving model to wafer_detection_xception_model.h5
# 256/256 - 42s - loss: 0.7896 - accuracy: 0.7309 - val_loss: 0.6114 - val_accuracy: 0.7945 - lr: 1.0000e-04 - 42s/epoch - 166ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.61141 to 0.60132, saving model to wafer_detection_xception_model.h5
# 256/256 - 45s - loss: 0.7679 - accuracy: 0.7392 - val_loss: 0.6013 - val_accuracy: 0.7997 - lr: 1.0000e-04 - 45s/epoch - 175ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.60132 to 0.59196, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 0.7564 - accuracy: 0.7426 - val_loss: 0.5920 - val_accuracy: 0.8006 - lr: 1.0000e-04 - 46s/epoch - 180ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.59196 to 0.58185, saving model to wafer_detection_xception_model.h5
# 256/256 - 45s - loss: 0.7355 - accuracy: 0.7440 - val_loss: 0.5819 - val_accuracy: 0.8024 - lr: 1.0000e-04 - 45s/epoch - 175ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.58185 to 0.57287, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.7299 - accuracy: 0.7537 - val_loss: 0.5729 - val_accuracy: 0.8050 - lr: 1.0000e-04 - 48s/epoch - 187ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.57287 to 0.57130, saving model to wafer_detection_xception_model.h5
# 256/256 - 52s - loss: 0.7236 - accuracy: 0.7517 - val_loss: 0.5713 - val_accuracy: 0.8046 - lr: 1.0000e-04 - 52s/epoch - 201ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.57130 to 0.56160, saving model to wafer_detection_xception_model.h5
# 256/256 - 49s - loss: 0.6960 - accuracy: 0.7672 - val_loss: 0.5616 - val_accuracy: 0.8070 - lr: 1.0000e-04 - 49s/epoch - 192ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.56160 to 0.55793, saving model to wafer_detection_xception_model.h5
# 256/256 - 50s - loss: 0.6878 - accuracy: 0.7696 - val_loss: 0.5579 - val_accuracy: 0.8082 - lr: 1.0000e-04 - 50s/epoch - 195ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.55793 to 0.55195, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.6809 - accuracy: 0.7659 - val_loss: 0.5519 - val_accuracy: 0.8124 - lr: 1.0000e-04 - 48s/epoch - 186ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.55195 to 0.54863, saving model to wafer_detection_xception_model.h5
# 256/256 - 54s - loss: 0.6671 - accuracy: 0.7752 - val_loss: 0.5486 - val_accuracy: 0.8109 - lr: 1.0000e-04 - 54s/epoch - 209ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.54863 to 0.54701, saving model to wafer_detection_xception_model.h5
# 256/256 - 52s - loss: 0.6711 - accuracy: 0.7763 - val_loss: 0.5470 - val_accuracy: 0.8117 - lr: 1.0000e-04 - 52s/epoch - 202ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.54701 to 0.54180, saving model to wafer_detection_xception_model.h5
# 256/256 - 44s - loss: 0.6554 - accuracy: 0.7774 - val_loss: 0.5418 - val_accuracy: 0.8134 - lr: 1.0000e-04 - 44s/epoch - 171ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.54180 to 0.53803, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.6550 - accuracy: 0.7801 - val_loss: 0.5380 - val_accuracy: 0.8148 - lr: 1.0000e-04 - 47s/epoch - 185ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.53803 to 0.53546, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.6400 - accuracy: 0.7820 - val_loss: 0.5355 - val_accuracy: 0.8161 - lr: 1.0000e-04 - 48s/epoch - 188ms/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 0.53546 to 0.53086, saving model to wafer_detection_xception_model.h5
# 256/256 - 50s - loss: 0.6368 - accuracy: 0.7860 - val_loss: 0.5309 - val_accuracy: 0.8170 - lr: 1.0000e-04 - 50s/epoch - 196ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.53086 to 0.52966, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.6317 - accuracy: 0.7895 - val_loss: 0.5297 - val_accuracy: 0.8193 - lr: 1.0000e-04 - 48s/epoch - 187ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.52966 to 0.52587, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.6206 - accuracy: 0.7899 - val_loss: 0.5259 - val_accuracy: 0.8219 - lr: 1.0000e-04 - 47s/epoch - 183ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.52587
# 256/256 - 40s - loss: 0.6238 - accuracy: 0.7880 - val_loss: 0.5260 - val_accuracy: 0.8200 - lr: 1.0000e-04 - 40s/epoch - 155ms/step
# Epoch 39/100
#
# Epoch 39: val_loss improved from 0.52587 to 0.51814, saving model to wafer_detection_xception_model.h5
# 256/256 - 45s - loss: 0.6133 - accuracy: 0.7919 - val_loss: 0.5181 - val_accuracy: 0.8244 - lr: 1.0000e-04 - 45s/epoch - 176ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 0.51814 to 0.51745, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 0.6176 - accuracy: 0.7915 - val_loss: 0.5175 - val_accuracy: 0.8254 - lr: 1.0000e-04 - 46s/epoch - 179ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.51745 to 0.51548, saving model to wafer_detection_xception_model.h5
# 256/256 - 52s - loss: 0.6042 - accuracy: 0.7955 - val_loss: 0.5155 - val_accuracy: 0.8246 - lr: 1.0000e-04 - 52s/epoch - 205ms/step
# Epoch 42/100
#
# Epoch 42: val_loss improved from 0.51548 to 0.51136, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.6009 - accuracy: 0.8006 - val_loss: 0.5114 - val_accuracy: 0.8251 - lr: 1.0000e-04 - 47s/epoch - 183ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.51136
# 256/256 - 39s - loss: 0.6005 - accuracy: 0.7984 - val_loss: 0.5125 - val_accuracy: 0.8254 - lr: 1.0000e-04 - 39s/epoch - 154ms/step
# Epoch 44/100
#
# Epoch 44: val_loss improved from 0.51136 to 0.51118, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.6007 - accuracy: 0.8023 - val_loss: 0.5112 - val_accuracy: 0.8251 - lr: 1.0000e-04 - 48s/epoch - 186ms/step
# Epoch 45/100
#
# Epoch 45: val_loss improved from 0.51118 to 0.50794, saving model to wafer_detection_xception_model.h5
# 256/256 - 53s - loss: 0.5900 - accuracy: 0.8028 - val_loss: 0.5079 - val_accuracy: 0.8281 - lr: 1.0000e-04 - 53s/epoch - 208ms/step
# Epoch 46/100
#
# Epoch 46: val_loss improved from 0.50794 to 0.50540, saving model to wafer_detection_xception_model.h5
# 256/256 - 53s - loss: 0.5879 - accuracy: 0.8024 - val_loss: 0.5054 - val_accuracy: 0.8283 - lr: 1.0000e-04 - 53s/epoch - 209ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.50540
# 256/256 - 41s - loss: 0.5744 - accuracy: 0.8082 - val_loss: 0.5058 - val_accuracy: 0.8281 - lr: 1.0000e-04 - 41s/epoch - 159ms/step
# Epoch 48/100
#
# Epoch 48: val_loss improved from 0.50540 to 0.50273, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 0.5680 - accuracy: 0.8104 - val_loss: 0.5027 - val_accuracy: 0.8290 - lr: 1.0000e-04 - 46s/epoch - 180ms/step
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.50273 to 0.50234, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.5663 - accuracy: 0.8106 - val_loss: 0.5023 - val_accuracy: 0.8300 - lr: 1.0000e-04 - 48s/epoch - 187ms/step
# Epoch 50/100
#
# Epoch 50: val_loss improved from 0.50234 to 0.49891, saving model to wafer_detection_xception_model.h5
# 256/256 - 54s - loss: 0.5616 - accuracy: 0.8116 - val_loss: 0.4989 - val_accuracy: 0.8295 - lr: 1.0000e-04 - 54s/epoch - 210ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.49891
# 256/256 - 40s - loss: 0.5678 - accuracy: 0.8093 - val_loss: 0.4991 - val_accuracy: 0.8303 - lr: 1.0000e-04 - 40s/epoch - 156ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.49891
# 256/256 - 39s - loss: 0.5688 - accuracy: 0.8096 - val_loss: 0.5003 - val_accuracy: 0.8300 - lr: 1.0000e-04 - 39s/epoch - 154ms/step
# Epoch 53/100
#
# Epoch 53: val_loss improved from 0.49891 to 0.49789, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.5493 - accuracy: 0.8155 - val_loss: 0.4979 - val_accuracy: 0.8310 - lr: 1.0000e-04 - 47s/epoch - 185ms/step
# Epoch 54/100
#
# Epoch 54: val_loss improved from 0.49789 to 0.49727, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 0.5568 - accuracy: 0.8148 - val_loss: 0.4973 - val_accuracy: 0.8313 - lr: 1.0000e-04 - 46s/epoch - 181ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.49727
# 256/256 - 40s - loss: 0.5449 - accuracy: 0.8161 - val_loss: 0.4983 - val_accuracy: 0.8330 - lr: 1.0000e-04 - 40s/epoch - 155ms/step
# Epoch 56/100
#
# Epoch 56: val_loss improved from 0.49727 to 0.49335, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.5363 - accuracy: 0.8164 - val_loss: 0.4934 - val_accuracy: 0.8339 - lr: 1.0000e-04 - 48s/epoch - 187ms/step
# Epoch 57/100
#
# Epoch 57: val_loss improved from 0.49335 to 0.49141, saving model to wafer_detection_xception_model.h5
# 256/256 - 52s - loss: 0.5476 - accuracy: 0.8183 - val_loss: 0.4914 - val_accuracy: 0.8344 - lr: 1.0000e-04 - 52s/epoch - 204ms/step
# Epoch 58/100
#
# Epoch 58: val_loss improved from 0.49141 to 0.49099, saving model to wafer_detection_xception_model.h5
# 256/256 - 49s - loss: 0.5393 - accuracy: 0.8234 - val_loss: 0.4910 - val_accuracy: 0.8342 - lr: 1.0000e-04 - 49s/epoch - 191ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.49099
# 256/256 - 41s - loss: 0.5418 - accuracy: 0.8187 - val_loss: 0.4933 - val_accuracy: 0.8349 - lr: 1.0000e-04 - 41s/epoch - 158ms/step
# Epoch 60/100
#
# Epoch 60: val_loss improved from 0.49099 to 0.49050, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.5382 - accuracy: 0.8191 - val_loss: 0.4905 - val_accuracy: 0.8354 - lr: 1.0000e-04 - 48s/epoch - 187ms/step
# Epoch 61/100
#
# Epoch 61: val_loss improved from 0.49050 to 0.49030, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.5379 - accuracy: 0.8229 - val_loss: 0.4903 - val_accuracy: 0.8337 - lr: 1.0000e-04 - 47s/epoch - 185ms/step
# Epoch 62/100
#
# Epoch 62: val_loss improved from 0.49030 to 0.48657, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.5299 - accuracy: 0.8242 - val_loss: 0.4866 - val_accuracy: 0.8352 - lr: 1.0000e-04 - 47s/epoch - 185ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.48657
# 256/256 - 41s - loss: 0.5330 - accuracy: 0.8237 - val_loss: 0.4893 - val_accuracy: 0.8344 - lr: 1.0000e-04 - 41s/epoch - 159ms/step
# Epoch 64/100
#
# Epoch 64: val_loss improved from 0.48657 to 0.48455, saving model to wafer_detection_xception_model.h5
# 256/256 - 52s - loss: 0.5264 - accuracy: 0.8253 - val_loss: 0.4846 - val_accuracy: 0.8349 - lr: 1.0000e-04 - 52s/epoch - 203ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.48455
# 256/256 - 41s - loss: 0.5269 - accuracy: 0.8228 - val_loss: 0.4889 - val_accuracy: 0.8359 - lr: 1.0000e-04 - 41s/epoch - 159ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.48455
# 256/256 - 40s - loss: 0.5239 - accuracy: 0.8242 - val_loss: 0.4874 - val_accuracy: 0.8366 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.48455
# 256/256 - 39s - loss: 0.5310 - accuracy: 0.8246 - val_loss: 0.4862 - val_accuracy: 0.8364 - lr: 1.0000e-04 - 39s/epoch - 154ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.48455
# 256/256 - 39s - loss: 0.5257 - accuracy: 0.8275 - val_loss: 0.4855 - val_accuracy: 0.8376 - lr: 1.0000e-04 - 39s/epoch - 154ms/step
# Epoch 69/100
#
# Epoch 69: val_loss improved from 0.48455 to 0.48245, saving model to wafer_detection_xception_model.h5
# 256/256 - 43s - loss: 0.5233 - accuracy: 0.8261 - val_loss: 0.4825 - val_accuracy: 0.8369 - lr: 1.0000e-04 - 43s/epoch - 169ms/step
# Epoch 70/100
#
# Epoch 70: val_loss improved from 0.48245 to 0.48156, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.5080 - accuracy: 0.8306 - val_loss: 0.4816 - val_accuracy: 0.8366 - lr: 1.0000e-04 - 48s/epoch - 187ms/step
# Epoch 71/100
#
# Epoch 71: val_loss improved from 0.48156 to 0.47947, saving model to wafer_detection_xception_model.h5
# 256/256 - 43s - loss: 0.5126 - accuracy: 0.8253 - val_loss: 0.4795 - val_accuracy: 0.8391 - lr: 1.0000e-04 - 43s/epoch - 168ms/step
# Epoch 72/100
#
# Epoch 72: val_loss improved from 0.47947 to 0.47863, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.5091 - accuracy: 0.8327 - val_loss: 0.4786 - val_accuracy: 0.8386 - lr: 1.0000e-04 - 48s/epoch - 188ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.47863
# 256/256 - 41s - loss: 0.4983 - accuracy: 0.8327 - val_loss: 0.4822 - val_accuracy: 0.8361 - lr: 1.0000e-04 - 41s/epoch - 159ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.47863
# 256/256 - 40s - loss: 0.5079 - accuracy: 0.8306 - val_loss: 0.4823 - val_accuracy: 0.8376 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.47863
# 256/256 - 40s - loss: 0.5048 - accuracy: 0.8309 - val_loss: 0.4799 - val_accuracy: 0.8393 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.47863
# 256/256 - 40s - loss: 0.4995 - accuracy: 0.8365 - val_loss: 0.4801 - val_accuracy: 0.8384 - lr: 1.0000e-04 - 40s/epoch - 154ms/step
# Epoch 77/100
#
# Epoch 77: val_loss improved from 0.47863 to 0.47812, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 0.4958 - accuracy: 0.8350 - val_loss: 0.4781 - val_accuracy: 0.8398 - lr: 1.0000e-04 - 46s/epoch - 178ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.47812
# 256/256 - 41s - loss: 0.4898 - accuracy: 0.8372 - val_loss: 0.4789 - val_accuracy: 0.8379 - lr: 1.0000e-04 - 41s/epoch - 159ms/step
# Epoch 79/100
#
# Epoch 79: val_loss improved from 0.47812 to 0.47643, saving model to wafer_detection_xception_model.h5
# 256/256 - 46s - loss: 0.4953 - accuracy: 0.8365 - val_loss: 0.4764 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 46s/epoch - 181ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.47643
# 256/256 - 41s - loss: 0.4896 - accuracy: 0.8398 - val_loss: 0.4765 - val_accuracy: 0.8401 - lr: 1.0000e-04 - 41s/epoch - 159ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.47643
# 256/256 - 39s - loss: 0.4950 - accuracy: 0.8339 - val_loss: 0.4800 - val_accuracy: 0.8393 - lr: 1.0000e-04 - 39s/epoch - 154ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.47643
# 256/256 - 40s - loss: 0.4871 - accuracy: 0.8378 - val_loss: 0.4793 - val_accuracy: 0.8384 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.47643
# 256/256 - 40s - loss: 0.4949 - accuracy: 0.8330 - val_loss: 0.4772 - val_accuracy: 0.8384 - lr: 1.0000e-04 - 40s/epoch - 154ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.47643
# 256/256 - 40s - loss: 0.4840 - accuracy: 0.8388 - val_loss: 0.4771 - val_accuracy: 0.8410 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 85/100
#
# Epoch 85: val_loss improved from 0.47643 to 0.47613, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.4936 - accuracy: 0.8365 - val_loss: 0.4761 - val_accuracy: 0.8393 - lr: 1.0000e-04 - 47s/epoch - 185ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.47613
# 256/256 - 41s - loss: 0.4886 - accuracy: 0.8368 - val_loss: 0.4767 - val_accuracy: 0.8384 - lr: 1.0000e-04 - 41s/epoch - 159ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.47613
# 256/256 - 39s - loss: 0.4847 - accuracy: 0.8387 - val_loss: 0.4804 - val_accuracy: 0.8388 - lr: 1.0000e-04 - 39s/epoch - 154ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.47613
# 256/256 - 40s - loss: 0.4850 - accuracy: 0.8373 - val_loss: 0.4800 - val_accuracy: 0.8384 - lr: 1.0000e-04 - 40s/epoch - 154ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.47613
# 256/256 - 40s - loss: 0.4795 - accuracy: 0.8399 - val_loss: 0.4765 - val_accuracy: 0.8391 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 90/100
#
# Epoch 90: val_loss improved from 0.47613 to 0.47274, saving model to wafer_detection_xception_model.h5
# 256/256 - 52s - loss: 0.4808 - accuracy: 0.8441 - val_loss: 0.4727 - val_accuracy: 0.8410 - lr: 1.0000e-04 - 52s/epoch - 202ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.47274
# 256/256 - 40s - loss: 0.4774 - accuracy: 0.8400 - val_loss: 0.4734 - val_accuracy: 0.8418 - lr: 1.0000e-04 - 40s/epoch - 156ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.47274
# 256/256 - 40s - loss: 0.4658 - accuracy: 0.8439 - val_loss: 0.4739 - val_accuracy: 0.8413 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.47274
# 256/256 - 39s - loss: 0.4699 - accuracy: 0.8425 - val_loss: 0.4740 - val_accuracy: 0.8406 - lr: 1.0000e-04 - 39s/epoch - 154ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.47274
# 256/256 - 40s - loss: 0.4789 - accuracy: 0.8429 - val_loss: 0.4732 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.47274
# 256/256 - 40s - loss: 0.4710 - accuracy: 0.8437 - val_loss: 0.4744 - val_accuracy: 0.8408 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 96/100
#
# Epoch 96: val_loss improved from 0.47274 to 0.47197, saving model to wafer_detection_xception_model.h5
# 256/256 - 48s - loss: 0.4640 - accuracy: 0.8448 - val_loss: 0.4720 - val_accuracy: 0.8420 - lr: 1.0000e-04 - 48s/epoch - 186ms/step
# Epoch 97/100
#
# Epoch 97: val_loss improved from 0.47197 to 0.47156, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 0.4628 - accuracy: 0.8467 - val_loss: 0.4716 - val_accuracy: 0.8425 - lr: 1.0000e-04 - 47s/epoch - 182ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.47156
# 256/256 - 40s - loss: 0.4682 - accuracy: 0.8444 - val_loss: 0.4719 - val_accuracy: 0.8415 - lr: 1.0000e-04 - 40s/epoch - 155ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.47156
# 256/256 - 40s - loss: 0.4645 - accuracy: 0.8486 - val_loss: 0.4746 - val_accuracy: 0.8410 - lr: 1.0000e-04 - 40s/epoch - 158ms/step
# Epoch 100/100
#
# Epoch 100: val_loss improved from 0.47156 to 0.47056, saving model to wafer_detection_xception_model.h5
# 256/256 - 45s - loss: 0.4680 - accuracy: 0.8420 - val_loss: 0.4706 - val_accuracy: 0.8425 - lr: 1.0000e-04 - 45s/epoch - 178ms/step

# %%
model_path = os.path.join(path, "model/Xception")
model.save(model_path)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 41). These functions will not be directly callable after loading.

# %%
# Accuracy plot
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# Loss plot
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
