# %% [markdown]
# <a href="https://colab.research.google.com/github/ShangWeiKuo/Portfolio/blob/main/Python/Classification/Multiclass/Wafer/Wafer_classification_Xception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 讀取 libraries
import numpy as np 
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline 

from keras import layers, Input, models
from keras.models import Model, Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.applications import Xception

import os
# 設定當前工作目錄
path="/content/drive/MyDrive/wafer/"
os.chdir(path)

print(os.listdir(path))

import warnings
warnings.filterwarnings("ignore")
# Out:
# ['Wafer classification_Densenet201.ipynb', 'wafer-defect-classification-by-deep-learning.ipynb', 'Untitled1.ipynb', 'Wafer detection.ipynb', 'wafer.zip', 'LSWMD.pkl', 'Wafer anomaly detection_AutoEncoder.ipynb', 'Wafer anomaly detection_Denoising AutoEncoder.ipynb', 'Wafer anomaly detection.ipynb', 'Wafer classification_KFold.ipynb', 'wafer_detection_densenet_model.h5', 'Wafer classification_Densenet201_PyTorch.ipynb', 'model', 'rawdata.npz', 'Wafer preprocess.ipynb', 'Model_evaluation_comparison.ipynb', 'Wafer classification_Densenet201_v2.ipynb', 'Wafer classification_Inception-v4.ipynb', 'wafer_detection_mobilenet_model.h5', 'Wafer classification_MobileNet-V2.ipynb', 'Wafer classification_EfficientNetB7.ipynb', 'wafer_detection_resnet_model.h5', 'Wafer classification_ResNet101.ipynb', 'Wafer classification_Xception.ipynb']

# %%
# 讀取資料(npz壓縮檔)
df=np.load('rawdata.npz')
X_train = df['X_train']
y_train = df['y_train']
df.close()

# %%
# 模型架構 (Xception)
def build_xception():
    xception = Xception(weights='imagenet', include_top=False)

    input = Input(shape=(64, 64, 3))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = xception(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(8, activation = 'softmax')(x)
 
    # model
    model = Model(input ,output)
    
    optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
# 呼叫模型
model = build_xception()
# EarlyStopping：可設定訓練提早結束的條件。
es = EarlyStopping(monitor='val_accuracy', mode='auto', verbose=1, patience=10)
# ReduceLROnPlateau：當訓練已無改善時，可以降低學習率，追求更細微的改善，找到更精準的最佳解。
Reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
# ModelCheckpoint：由於訓練過程耗時，有可能訓練一半就當掉，因此，我們可以利用這個 Callback，在每一個檢查點(Checkpoint)存檔，下次執行時，就可以從中斷點繼續訓練。
checkpoint = ModelCheckpoint('wafer_detection_xception_model.h5', verbose=1, save_best_only=True)

# 訓練資料
History = model.fit(X_train, y_train, 
           epochs=100, 
           batch_size=64,
           verbose=2,
           callbacks=[Reduce, es, checkpoint],
           validation_split=0.2, # 每次訓練將 Train data 分割 20% 作為 Validation data
           workers=8)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 3)         84
#
#  xception (Functional)       (None, None, None, 2048)  20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization_4 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 21,397,380
# Trainable params: 21,338,244
# Non-trainable params: 59,136
# _________________________________________________________________
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.46437, saving model to wafer_detection_xception_model.h5
# 256/256 - 47s - loss: 2.5330 - accuracy: 0.2395 - val_loss: 1.4644 - val_accuracy: 0.5300 - lr: 1.0000e-04 - 47s/epoch - 185ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.46437 to 1.33258, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 1.7620 - accuracy: 0.4293 - val_loss: 1.3326 - val_accuracy: 0.5557 - lr: 1.0000e-04 - 32s/epoch - 125ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.33258 to 1.23663, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 1.5619 - accuracy: 0.5007 - val_loss: 1.2366 - val_accuracy: 0.5787 - lr: 1.0000e-04 - 32s/epoch - 123ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.23663 to 1.15793, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 1.4444 - accuracy: 0.5349 - val_loss: 1.1579 - val_accuracy: 0.5966 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.15793 to 1.06299, saving model to wafer_detection_xception_model.h5
# 256/256 - 33s - loss: 1.3455 - accuracy: 0.5566 - val_loss: 1.0630 - val_accuracy: 0.6302 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.06299 to 0.97183, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 1.2164 - accuracy: 0.6028 - val_loss: 0.9718 - val_accuracy: 0.6539 - lr: 1.0000e-04 - 32s/epoch - 125ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.97183 to 0.89994, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 1.1094 - accuracy: 0.6330 - val_loss: 0.8999 - val_accuracy: 0.6765 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.89994 to 0.83149, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 1.0328 - accuracy: 0.6528 - val_loss: 0.8315 - val_accuracy: 0.6997 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.83149 to 0.76800, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.9558 - accuracy: 0.6806 - val_loss: 0.7680 - val_accuracy: 0.7240 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.76800 to 0.72573, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.9015 - accuracy: 0.6922 - val_loss: 0.7257 - val_accuracy: 0.7416 - lr: 1.0000e-04 - 32s/epoch - 125ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.72573 to 0.68790, saving model to wafer_detection_xception_model.h5
# 256/256 - 33s - loss: 0.8567 - accuracy: 0.7128 - val_loss: 0.6879 - val_accuracy: 0.7617 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.68790 to 0.66035, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.8307 - accuracy: 0.7232 - val_loss: 0.6603 - val_accuracy: 0.7759 - lr: 1.0000e-04 - 31s/epoch - 123ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.66035 to 0.63297, saving model to wafer_detection_xception_model.h5
# 256/256 - 33s - loss: 0.7615 - accuracy: 0.7406 - val_loss: 0.6330 - val_accuracy: 0.7864 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.63297 to 0.61917, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.7645 - accuracy: 0.7420 - val_loss: 0.6192 - val_accuracy: 0.7923 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.61917 to 0.60313, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.7342 - accuracy: 0.7525 - val_loss: 0.6031 - val_accuracy: 0.7975 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.60313 to 0.58940, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.7081 - accuracy: 0.7583 - val_loss: 0.5894 - val_accuracy: 0.7994 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.58940 to 0.57788, saving model to wafer_detection_xception_model.h5
# 256/256 - 33s - loss: 0.6925 - accuracy: 0.7661 - val_loss: 0.5779 - val_accuracy: 0.8053 - lr: 1.0000e-04 - 33s/epoch - 127ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.57788 to 0.56452, saving model to wafer_detection_xception_model.h5
# 256/256 - 34s - loss: 0.6761 - accuracy: 0.7720 - val_loss: 0.5645 - val_accuracy: 0.8092 - lr: 1.0000e-04 - 34s/epoch - 132ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.56452 to 0.55882, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.6483 - accuracy: 0.7799 - val_loss: 0.5588 - val_accuracy: 0.8121 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.55882 to 0.55006, saving model to wafer_detection_xception_model.h5
# 256/256 - 33s - loss: 0.6398 - accuracy: 0.7822 - val_loss: 0.5501 - val_accuracy: 0.8126 - lr: 1.0000e-04 - 33s/epoch - 128ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.55006 to 0.54987, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.6327 - accuracy: 0.7837 - val_loss: 0.5499 - val_accuracy: 0.8129 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.54987 to 0.53990, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.6209 - accuracy: 0.7886 - val_loss: 0.5399 - val_accuracy: 0.8151 - lr: 1.0000e-04 - 32s/epoch - 125ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.53990 to 0.53861, saving model to wafer_detection_xception_model.h5
# 256/256 - 34s - loss: 0.6108 - accuracy: 0.7914 - val_loss: 0.5386 - val_accuracy: 0.8158 - lr: 1.0000e-04 - 34s/epoch - 131ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.53861 to 0.53015, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.6154 - accuracy: 0.7923 - val_loss: 0.5302 - val_accuracy: 0.8163 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.53015 to 0.52731, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5920 - accuracy: 0.7962 - val_loss: 0.5273 - val_accuracy: 0.8173 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.52731 to 0.52154, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.6025 - accuracy: 0.7988 - val_loss: 0.5215 - val_accuracy: 0.8173 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.52154 to 0.51685, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5798 - accuracy: 0.7998 - val_loss: 0.5169 - val_accuracy: 0.8200 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.51685 to 0.51487, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5650 - accuracy: 0.8078 - val_loss: 0.5149 - val_accuracy: 0.8188 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.51487 to 0.51218, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5603 - accuracy: 0.8071 - val_loss: 0.5122 - val_accuracy: 0.8188 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.51218 to 0.50633, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5585 - accuracy: 0.8112 - val_loss: 0.5063 - val_accuracy: 0.8222 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.50633 to 0.50286, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5434 - accuracy: 0.8148 - val_loss: 0.5029 - val_accuracy: 0.8234 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 0.50286 to 0.50170, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.5344 - accuracy: 0.8179 - val_loss: 0.5017 - val_accuracy: 0.8229 - lr: 1.0000e-04 - 31s/epoch - 123ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.50170 to 0.49880, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5390 - accuracy: 0.8198 - val_loss: 0.4988 - val_accuracy: 0.8266 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.49880 to 0.49857, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5371 - accuracy: 0.8186 - val_loss: 0.4986 - val_accuracy: 0.8288 - lr: 1.0000e-04 - 32s/epoch - 127ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.49857 to 0.49804, saving model to wafer_detection_xception_model.h5
# 256/256 - 33s - loss: 0.5143 - accuracy: 0.8239 - val_loss: 0.4980 - val_accuracy: 0.8268 - lr: 1.0000e-04 - 33s/epoch - 129ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.49804 to 0.49431, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5174 - accuracy: 0.8249 - val_loss: 0.4943 - val_accuracy: 0.8273 - lr: 1.0000e-04 - 32s/epoch - 123ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.49431
# 256/256 - 29s - loss: 0.5179 - accuracy: 0.8195 - val_loss: 0.5013 - val_accuracy: 0.8239 - lr: 1.0000e-04 - 29s/epoch - 113ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.49431 to 0.48899, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5307 - accuracy: 0.8168 - val_loss: 0.4890 - val_accuracy: 0.8290 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.48899 to 0.48710, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5184 - accuracy: 0.8237 - val_loss: 0.4871 - val_accuracy: 0.8305 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.48710 to 0.48462, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.5052 - accuracy: 0.8265 - val_loss: 0.4846 - val_accuracy: 0.8276 - lr: 1.0000e-04 - 32s/epoch - 126ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.48462
# 256/256 - 29s - loss: 0.5088 - accuracy: 0.8251 - val_loss: 0.4950 - val_accuracy: 0.8264 - lr: 1.0000e-04 - 29s/epoch - 113ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.48462
# 256/256 - 29s - loss: 0.4962 - accuracy: 0.8285 - val_loss: 0.4846 - val_accuracy: 0.8317 - lr: 1.0000e-04 - 29s/epoch - 112ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.48462 to 0.48236, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4993 - accuracy: 0.8276 - val_loss: 0.4824 - val_accuracy: 0.8320 - lr: 1.0000e-04 - 31s/epoch - 122ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss improved from 0.48236 to 0.48039, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4941 - accuracy: 0.8325 - val_loss: 0.4804 - val_accuracy: 0.8322 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 0.48039 to 0.47990, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4858 - accuracy: 0.8314 - val_loss: 0.4799 - val_accuracy: 0.8320 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 0.47990 to 0.47897, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4805 - accuracy: 0.8338 - val_loss: 0.4790 - val_accuracy: 0.8320 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.47897 to 0.47539, saving model to wafer_detection_xception_model.h5
# 256/256 - 34s - loss: 0.4800 - accuracy: 0.8354 - val_loss: 0.4754 - val_accuracy: 0.8344 - lr: 1.0000e-04 - 34s/epoch - 131ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.47539
# 256/256 - 29s - loss: 0.4711 - accuracy: 0.8357 - val_loss: 0.4768 - val_accuracy: 0.8322 - lr: 1.0000e-04 - 29s/epoch - 114ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 0.47539 to 0.47462, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4865 - accuracy: 0.8349 - val_loss: 0.4746 - val_accuracy: 0.8357 - lr: 1.0000e-04 - 31s/epoch - 123ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss improved from 0.47462 to 0.47220, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4754 - accuracy: 0.8369 - val_loss: 0.4722 - val_accuracy: 0.8349 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.47220 to 0.47082, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4693 - accuracy: 0.8377 - val_loss: 0.4708 - val_accuracy: 0.8374 - lr: 1.0000e-04 - 32s/epoch - 125ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.47082
# 256/256 - 30s - loss: 0.4704 - accuracy: 0.8393 - val_loss: 0.4732 - val_accuracy: 0.8339 - lr: 1.0000e-04 - 30s/epoch - 116ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.47082
# 256/256 - 29s - loss: 0.4668 - accuracy: 0.8400 - val_loss: 0.4729 - val_accuracy: 0.8374 - lr: 1.0000e-04 - 29s/epoch - 112ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.47082 to 0.47017, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4585 - accuracy: 0.8415 - val_loss: 0.4702 - val_accuracy: 0.8349 - lr: 1.0000e-04 - 31s/epoch - 122ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.47017 to 0.46818, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4691 - accuracy: 0.8402 - val_loss: 0.4682 - val_accuracy: 0.8384 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.46818
# 256/256 - 28s - loss: 0.4524 - accuracy: 0.8459 - val_loss: 0.4683 - val_accuracy: 0.8359 - lr: 1.0000e-04 - 28s/epoch - 111ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.46818
# 256/256 - 28s - loss: 0.4684 - accuracy: 0.8397 - val_loss: 0.4695 - val_accuracy: 0.8354 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss improved from 0.46818 to 0.46585, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4554 - accuracy: 0.8441 - val_loss: 0.4659 - val_accuracy: 0.8388 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 0.46585 to 0.46556, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4488 - accuracy: 0.8448 - val_loss: 0.4656 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 31s/epoch - 122ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss improved from 0.46556 to 0.46499, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4596 - accuracy: 0.8417 - val_loss: 0.4650 - val_accuracy: 0.8381 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss improved from 0.46499 to 0.46378, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4413 - accuracy: 0.8482 - val_loss: 0.4638 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss improved from 0.46378 to 0.46302, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4413 - accuracy: 0.8485 - val_loss: 0.4630 - val_accuracy: 0.8398 - lr: 1.0000e-04 - 31s/epoch - 122ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.46302
# 256/256 - 28s - loss: 0.4464 - accuracy: 0.8475 - val_loss: 0.4638 - val_accuracy: 0.8406 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 0.46302 to 0.46124, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4493 - accuracy: 0.8448 - val_loss: 0.4612 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 31s/epoch - 120ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss improved from 0.46124 to 0.46046, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4373 - accuracy: 0.8523 - val_loss: 0.4605 - val_accuracy: 0.8391 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.46046
# 256/256 - 28s - loss: 0.4402 - accuracy: 0.8480 - val_loss: 0.4605 - val_accuracy: 0.8391 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss improved from 0.46046 to 0.46000, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4267 - accuracy: 0.8516 - val_loss: 0.4600 - val_accuracy: 0.8398 - lr: 1.0000e-04 - 31s/epoch - 120ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.46000
# 256/256 - 29s - loss: 0.4370 - accuracy: 0.8551 - val_loss: 0.4621 - val_accuracy: 0.8379 - lr: 1.0000e-04 - 29s/epoch - 114ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss improved from 0.46000 to 0.45983, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4319 - accuracy: 0.8531 - val_loss: 0.4598 - val_accuracy: 0.8393 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 70/100
#
# Epoch 00070: val_loss improved from 0.45983 to 0.45744, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4339 - accuracy: 0.8510 - val_loss: 0.4574 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 31s/epoch - 122ms/step
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.45744
# 256/256 - 28s - loss: 0.4306 - accuracy: 0.8536 - val_loss: 0.4588 - val_accuracy: 0.8415 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 0.45744 to 0.45676, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4436 - accuracy: 0.8488 - val_loss: 0.4568 - val_accuracy: 0.8401 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.45676
# 256/256 - 28s - loss: 0.4376 - accuracy: 0.8480 - val_loss: 0.4666 - val_accuracy: 0.8352 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.45676
# 256/256 - 29s - loss: 0.4264 - accuracy: 0.8558 - val_loss: 0.4733 - val_accuracy: 0.8315 - lr: 1.0000e-04 - 29s/epoch - 113ms/step
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.45676
# 256/256 - 28s - loss: 0.4185 - accuracy: 0.8535 - val_loss: 0.4576 - val_accuracy: 0.8408 - lr: 1.0000e-04 - 28s/epoch - 109ms/step
# Epoch 76/100
#
# Epoch 00076: val_loss improved from 0.45676 to 0.45416, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4175 - accuracy: 0.8562 - val_loss: 0.4542 - val_accuracy: 0.8420 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.45416
# 256/256 - 28s - loss: 0.4063 - accuracy: 0.8578 - val_loss: 0.4544 - val_accuracy: 0.8420 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 78/100
#
# Epoch 00078: val_loss improved from 0.45416 to 0.45179, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4150 - accuracy: 0.8572 - val_loss: 0.4518 - val_accuracy: 0.8445 - lr: 1.0000e-04 - 31s/epoch - 120ms/step
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.45179
# 256/256 - 29s - loss: 0.4189 - accuracy: 0.8547 - val_loss: 0.4704 - val_accuracy: 0.8327 - lr: 1.0000e-04 - 29s/epoch - 114ms/step
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.45179
# 256/256 - 29s - loss: 0.4197 - accuracy: 0.8594 - val_loss: 0.4540 - val_accuracy: 0.8408 - lr: 1.0000e-04 - 29s/epoch - 113ms/step
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.45179
# 256/256 - 28s - loss: 0.4208 - accuracy: 0.8600 - val_loss: 0.4529 - val_accuracy: 0.8420 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.45179
# 256/256 - 28s - loss: 0.4076 - accuracy: 0.8594 - val_loss: 0.4815 - val_accuracy: 0.8288 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.45179
# 256/256 - 28s - loss: 0.4163 - accuracy: 0.8573 - val_loss: 0.4524 - val_accuracy: 0.8445 - lr: 1.0000e-04 - 28s/epoch - 109ms/step
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.45179
# 256/256 - 28s - loss: 0.4101 - accuracy: 0.8605 - val_loss: 0.4520 - val_accuracy: 0.8420 - lr: 1.0000e-04 - 28s/epoch - 109ms/step
# Epoch 85/100
#
# Epoch 00085: val_loss improved from 0.45179 to 0.45166, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4121 - accuracy: 0.8594 - val_loss: 0.4517 - val_accuracy: 0.8450 - lr: 1.0000e-04 - 31s/epoch - 120ms/step
# Epoch 86/100
#
# Epoch 00086: val_loss improved from 0.45166 to 0.45074, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4063 - accuracy: 0.8604 - val_loss: 0.4507 - val_accuracy: 0.8435 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 87/100
#
# Epoch 00087: val_loss improved from 0.45074 to 0.45056, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4047 - accuracy: 0.8603 - val_loss: 0.4506 - val_accuracy: 0.8425 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 88/100
#
# Epoch 00088: val_loss improved from 0.45056 to 0.45017, saving model to wafer_detection_xception_model.h5
# 256/256 - 32s - loss: 0.4062 - accuracy: 0.8566 - val_loss: 0.4502 - val_accuracy: 0.8455 - lr: 1.0000e-04 - 32s/epoch - 124ms/step
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.45017
# 256/256 - 29s - loss: 0.4167 - accuracy: 0.8571 - val_loss: 0.4504 - val_accuracy: 0.8415 - lr: 1.0000e-04 - 29s/epoch - 114ms/step
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.45017
# 256/256 - 29s - loss: 0.3961 - accuracy: 0.8628 - val_loss: 0.4512 - val_accuracy: 0.8430 - lr: 1.0000e-04 - 29s/epoch - 113ms/step
# Epoch 91/100
#
# Epoch 00091: val_loss improved from 0.45017 to 0.44836, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4127 - accuracy: 0.8590 - val_loss: 0.4484 - val_accuracy: 0.8452 - lr: 1.0000e-04 - 31s/epoch - 120ms/step
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.44836
# 256/256 - 29s - loss: 0.4052 - accuracy: 0.8613 - val_loss: 0.4493 - val_accuracy: 0.8450 - lr: 1.0000e-04 - 29s/epoch - 114ms/step
# Epoch 93/100
#
# Epoch 00093: val_loss improved from 0.44836 to 0.44829, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4013 - accuracy: 0.8628 - val_loss: 0.4483 - val_accuracy: 0.8467 - lr: 1.0000e-04 - 31s/epoch - 123ms/step
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.44829
# 256/256 - 29s - loss: 0.4108 - accuracy: 0.8573 - val_loss: 0.4490 - val_accuracy: 0.8450 - lr: 1.0000e-04 - 29s/epoch - 114ms/step
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.44829
# 256/256 - 28s - loss: 0.4016 - accuracy: 0.8629 - val_loss: 0.4488 - val_accuracy: 0.8428 - lr: 1.0000e-04 - 28s/epoch - 109ms/step
# Epoch 96/100
#
# Epoch 00096: val_loss improved from 0.44829 to 0.44734, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.4064 - accuracy: 0.8614 - val_loss: 0.4473 - val_accuracy: 0.8469 - lr: 1.0000e-04 - 31s/epoch - 120ms/step
# Epoch 97/100
#
# Epoch 00097: val_loss improved from 0.44734 to 0.44721, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.3947 - accuracy: 0.8624 - val_loss: 0.4472 - val_accuracy: 0.8459 - lr: 1.0000e-04 - 31s/epoch - 121ms/step
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.44721
# 256/256 - 28s - loss: 0.3971 - accuracy: 0.8644 - val_loss: 0.4638 - val_accuracy: 0.8325 - lr: 1.0000e-04 - 28s/epoch - 110ms/step
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.44721
# 256/256 - 28s - loss: 0.3991 - accuracy: 0.8638 - val_loss: 0.4473 - val_accuracy: 0.8457 - lr: 1.0000e-04 - 28s/epoch - 109ms/step
# Epoch 100/100
#
# Epoch 00100: val_loss improved from 0.44721 to 0.44444, saving model to wafer_detection_xception_model.h5
# 256/256 - 31s - loss: 0.3947 - accuracy: 0.8624 - val_loss: 0.4444 - val_accuracy: 0.8486 - lr: 1.0000e-04 - 31s/epoch - 122ms/step

# %%
model_path = path + "model/Xception"
model.save(model_path)
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/wafer/model/Xception/assets

# %%
# Accuracy plot 
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# Loss plot
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
